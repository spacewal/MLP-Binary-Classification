# %% [markdown]
# <a href="https://colab.research.google.com/github/spacewal/MLP-Binary-Classification/blob/main/MLP_Binary_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Complete the Tutorial:

# %%
from pandas import read_csv

# Load the dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt'
data = read_csv(url, header=None)

# %%
import pandas as pd

data.head()
# Out:
#          0       1       2        3  4
# 0  3.62160  8.6661 -2.8073 -0.44699  0
# 1  4.54590  8.1674 -2.4586 -1.46210  0
# 2  3.86600 -2.6383  1.9242  0.10645  0
# 3  3.45660  9.5228 -4.0112 -3.59440  0
# 4  0.32924 -4.4552  4.5718 -0.98880  0

# %%
from sklearn.preprocessing import LabelEncoder

# Split data into input (X) and output (y)
X, y = data.values[:, :-1], data.values[:, -1]
X = X.astype('float32')

# Convert class labels to binary
y = LabelEncoder().fit_transform(y)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Define the MLP model
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(X.shape[1],)))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit the model to the data
model.fit(X, y, epochs=50, batch_size=32, verbose=0)

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"Model Accuracy: {accuracy:.3f}")

# Test a prediction
sample = [3.6216,  8.6661,  -2.8073, -0.44699]
prediction = model.predict([sample])
print(f"Predicted Class: {round(prediction[0][0])}")
# Out:
# Model Accuracy: 1.000
# 1/1 [==============================] - 0s 117ms/step
# Predicted Class: 0

# %% [markdown]
# # Create a New Model:

# %%
from pandas import read_csv

# Load the dataset
url = 'https://raw.githubusercontent.com/spacewal/MLP-Binary-Classification/main/breast-cancer.csv'
data = read_csv(url)

# %%
import pandas as pd

# Look at the data to viz it
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Split the data into trainning and testing sets
# Exclude 'id' and 'diagnosis' from X, and use 'diagnosis' as y
X = data.drop(columns=['id', 'diagnosis']).values
y = data['diagnosis'].values

# Convert to float32 for input features
X = X.astype('float32')

# Convert class labels to binary
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# Define the MLP model
model = Sequential()
model.add(Dense(10, activation='elu', input_shape=(X.shape[1],)))
model.add(Dropout(0.2))  # Dropout 20% of the nodes in the previous layer during training
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit the model to the data
model.fit(X, y, epochs=200, batch_size= 50, verbose=0)

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X, y, verbose=0)
print(f"Model Accuracy: {accuracy:.3f}")
# Out:
# Model Accuracy: 0.944

# %%
# Test a prediction
sample = random_data_df
prediction = model.predict([sample])
print(f"Predicted Class: {round(prediction[0][0])}")
# Out:
# 18/18 [==============================] - 0s 1ms/step
# Predicted Class: 1
